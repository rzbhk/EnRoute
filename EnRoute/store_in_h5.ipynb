# %%
import pandas as pd

# %%
import numpy as np

# %%
qdf = pd.read_csv("london_u6.6_5sp_5.0bmult.que.out.csv",sep=';')

# %%
tdf = pd.read_csv("london_u6.6_5sp_5.0bmult.tripinfos.out.csv",sep=';')

# %%
edf = pd.read_csv("london_u6.6_5sp_5.0bmult.edgeinfo.csv",sep=';')

# %%
fcddf = pd.read_csv("london_u6.6_5sp_5.0bmult.fcd.out.csv",sep=';')

# %%
store = pd.HDFStore("london_dua60.h5")

# %%
store["tripinfos_df"] = tdf

# %%
store["edgeinfo_df"] = edf

# %%
qdf["lane_id"] = qdf["lane_id"].astype("str")

# %%
store["queue_df"] = qdf

# %%
fcddf["vehicle_id"] = fcddf["vehicle_id"].astype("str")

# %%
fcddf = fcddf[["timestep_time","vehicle_lane","vehicle_id","vehicle_pos","vehicle_x","vehicle_y","vehicle_speed"]]

# %%
fcddf["timestep_time"] = fcddf["timestep_time"].astype(np.int32)
# Out:
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
fcddf
# Out:
#           timestep_time    vehicle_lane vehicle_id  vehicle_pos  vehicle_x  \
# 0                     0     130111983_0       5502         5.10   15076.47
# 1                     1   156297569#0_1      10021         5.10   16459.81
# 2                     1   156297569#0_0      10090         5.10   16460.17
# 3                     1   315328585#0_0      10946         5.10   45376.82
# 4                     1      23125069_0      13979         5.10   31012.72
# 5                     1     2372214#0_0      14278         5.10   25914.66
# 6                     1     2372214#0_1      14840         5.10   25911.86
# 7                     1     2599786#0_0      16012         5.10   17727.20
# 8                     1     4316126#1_0      16962         5.10   39497.39
# 9                     1   238222125#0_0      17216         5.10   39125.81
# 10                    1  -364043290#2_0      19750         5.10   30270.01
# ...

# %%
store["fcd_df"] = fcddf

# %%
store
